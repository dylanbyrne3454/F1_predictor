# %%
import pandas as pd
import fastf1
import time

# %% [markdown]
# # Getting the data

# %% [markdown]
# ## Creating training data

# %%
fastf1.Cache.enable_cache("f1_cache")

training_seasons = [2022, 2023, 2024]
all_results = []

for year in training_seasons:
    schedule = fastf1.get_event_schedule(year)

    for index, event in schedule.iterrows():
        if event['EventFormat'] == 'testing':
            continue
        try:
            time.sleep(3)
            session = fastf1.get_session(year, event['RoundNumber'], 'R')
            session.load(laps=False, telemetry=False, weather=True)

            results = session.results[['Abbreviation', 'TeamName', 
                                       'GridPosition', 'Position', 'Points']].copy()
            
            results['Season'] = year
            results['RoundNumber'] = event['RoundNumber']
            results['EventName'] = event['EventName']
            results['Podium'] = (results['Position'] <= 3).astype(int)

            # Weather data
            weather_data = session.weather_data  # no parentheses - it's a property not a method
            results['Rainfall'] = weather_data['Rainfall'].any()
            results['AirTemp'] = weather_data['AirTemp'].median()  # capital T in AirTemp

            # Qualifying session
         #   session_q = fastf1.get_session(year, event['RoundNumber'], 'Q')
          #  session_q.load(laps=False, telemetry=False)
            
            #quali_results = session_q.results[['Abbreviation', 'Q3']].copy()
            #quali_results = quali_results.rename(columns={'Q3': 'QualiTime'})
           # quali_results['Season'] = year
           # quali_results['RoundNumber'] = event['RoundNumber']

            # Merge quali into results
           # results = results.merge(quali_results, on=['Abbreviation', 'Season', 'RoundNumber'], how='left')
            
            all_results.append(results)  # only one append
            print(f"✓ {event['EventName']} {year}")

        except Exception as e:
            print(f"✗ Could not load {event['EventName']}: {e}")

results_df = pd.concat(all_results, ignore_index=True)
results_df.to_csv("data/race_results_22_24.csv", index=False)
print(f"Done — {len(results_df)} rows")
# Out:
# Request for URL https://raw.githubusercontent.com/theOehrly/f1schedule/master/schedule_2022.json failed; using cached response
# Traceback (most recent call last):
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\requests_cache\session.py", line 292, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\requests_cache\session.py", line 260, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\fastf1\req.py", line 110, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\fastf1\req.py", line 80, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.exceptions.RateLimitExceededError: any API: 500 calls/h
# Request for URL https://raw.githubusercontent.com/theOehrly/f1schedule/master/schedule_2022.json failed; using cached response
# Traceback (most recent call last):
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\requests_cache\session.py", line 292, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\requests_cache\session.py", line 260, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\fastf1\req.py", line 110, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\fastf1\req.py", line 80, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.exceptions.RateLimitExceededError: any API: 500 calls/h
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.8.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://api.jolpi.ca/ergast/f1/2022/1/results.json failed; using cached response
# Traceback (most recent call last):
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\requests_cache\session.py", line 292, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\requests_cache\session.py", line 260, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\fastf1\req.py", line 110, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\fastf1\req.py", line 80, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.exceptions.RateLimitExceededError: any API: 500 calls/h
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '55', '44', '63', '20', '77', '31', '22', '14', '24', '47', '18', '23', '3', '4', '6', '27', '11', '1', '10']
# ✓ Bahrain Grand Prix 2022
# Request for URL https://raw.githubusercontent.com/theOehrly/f1schedule/master/schedule_2022.json failed; using cached response
# Traceback (most recent call last):
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\requests_cache\session.py", line 292, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\requests_cache\session.py", line 260, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\fastf1\req.py", line 110, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\fastf1\req.py", line 80, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.exceptions.RateLimitExceededError: any API: 500 calls/h
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Race [v3.8.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# Request for URL https://api.jolpi.ca/ergast/f1/2022/2/results.json failed; using cached response
# Traceback (most recent call last):
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\requests_cache\session.py", line 292, in _resend
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\requests_cache\session.py", line 260, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\fastf1\req.py", line 110, in send
#     lim.limit()
#     ~~~~~~~~~^^
#   File "c:\Users\dylan\Documents\Projects\F1_predictor\venv\Lib\site-packages\fastf1\req.py", line 80, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.exceptions.RateLimitExceededError: any API: 500 calls/h
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '55', '11', '63', '31', '4', '10', '20', '44', '24', '27', '18', '23', '77', '14', '3', '6', '22', '47']
# ✓ Saudi Arabian Grand Prix 2022
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 13
#      11     continue
#      12 try:
# ---> 13     time.sleep(3)
#      14     session = fastf1.get_session(year, event['RoundNumber'], 'R')
#      15     session.load(laps=False, telemetry=False, weather=True)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create testing data

# %%
testing_seasons = [2025]
all_results_25 = []

for year in testing_seasons:
    schedule = fastf1.get_event_schedule(year)

    for index, event in schedule.iterrows():
        if event['EventFormat'] == 'testing':
            continue
        try:
            time.sleep(2)
            session = fastf1.get_session(year, event['RoundNumber'], 'R')
            session.load(laps=False, telemetry=False, weather=True)

            results = session.results[['Abbreviation', 'TeamName', 
                                       'GridPosition', 'Position', 'Points']].copy()
            
            results['Season'] = year
            results['RoundNumber'] = event['RoundNumber']
            results['EventName'] = event['EventName']
            results['Podium'] = (results['Position'] <= 3).astype(int)

            weather_data = session.weather_data  # no parentheses - it's a property not a method
            results['Rainfall'] = weather_data['Rainfall'].any()
            results['AirTemp'] = weather_data['AirTemp'].median()  # capital T in AirTemp

            # Qualifying data
            session_q = fastf1.get_session(year, event['RoundNumber'], 'Q')
            session_q.load(laps=False, telemetry=False)
            
            quali_results = session_q.results[['Abbreviation', 'Q3']].copy()
            quali_results = quali_results.rename(columns={'Q3': 'QualiTime'})
            quali_results['Season'] = year
            quali_results['RoundNumber'] = event['RoundNumber']

            # Merge quali into results
            results = results.merge(quali_results, on=['Abbreviation', 'Season', 'RoundNumber'], how='left')
            all_results_25.append(results)  # only one append
            print(f"✓ {event['EventName']} {year}")

        except Exception as e:
            print(f"✗ Could not load {event['EventName']}: {e}")

results_25_df = pd.concat(all_results_25, ignore_index=True)
results_25_df.to_csv("data/race_results_25.csv", index=False)
print(f"Done — {len(results_25_df)} rows")
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['4', '1', '63', '12', '23', '18', '27', '16', '81', '44', '10', '22', '31', '87', '30', '5', '14', '55', '7', '6']
# ✓ Australian Grand Prix 2025
# core           INFO 	Loading data for Chinese Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['81', '4', '63', '1', '31', '12', '23', '87', '18', '55', '6', '30', '7', '5', '27', '22', '14', '16', '44', '10']
# ✓ Chinese Grand Prix 2025
# core           INFO 	Loading data for Japanese Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '81', '16', '63', '12', '44', '6', '23', '87', '14', '22', '10', '55', '7', '27', '30', '31', '5', '18']
# ✓ Japanese Grand Prix 2025
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['81', '63', '4', '16', '44', '1', '10', '31', '22', '87', '12', '23', '6', '7', '14', '30', '18', '5', '55', '27']
# ✓ Bahrain Grand Prix 2025
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['81', '1', '16', '4', '63', '12', '44', '55', '23', '6', '14', '30', '87', '31', '27', '18', '7', '5', '22', '10']
# ✓ Saudi Arabian Grand Prix 2025
# core           INFO 	Loading data for Miami Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['81', '4', '63', '1', '23', '12', '16', '44', '55', '22', '6', '31', '10', '27', '14', '18', '30', '5', '87', '7']
# ✓ Miami Grand Prix 2025
# core           INFO 	Loading data for Emilia Romagna Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '81', '44', '23', '16', '63', '55', '6', '22', '14', '27', '10', '30', '18', '43', '87', '5', '12', '31']
# ✓ Emilia Romagna Grand Prix 2025
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['4', '16', '81', '1', '44', '6', '31', '30', '23', '55', '63', '87', '43', '5', '18', '27', '22', '12', '14', '10']
# ✓ Monaco Grand Prix 2025
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 19 drivers: ['81', '4', '16', '63', '27', '44', '6', '10', '14', '1', '30', '5', '22', '55', '43', '31', '87', '12', '23']
# ✓ Spanish Grand Prix 2025
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['63', '1', '12', '81', '16', '44', '14', '27', '31', '55', '87', '22', '43', '5', '10', '6', '18', '4', '30', '23']
# ✓ Canadian Grand Prix 2025
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['4', '81', '16', '44', '63', '30', '14', '5', '27', '31', '87', '6', '10', '18', '43', '22', '23', '1', '12', '55']
# ✓ Austrian Grand Prix 2025
# core           INFO 	Loading data for British Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['4', '81', '27', '44', '1', '10', '18', '23', '14', '63', '87', '55', '31', '16', '22', '12', '6', '5', '30', '43']
# ✓ British Grand Prix 2025
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['81', '4', '16', '1', '63', '23', '44', '30', '5', '10', '87', '27', '22', '18', '31', '12', '14', '55', '43', '6']
# ✓ Belgian Grand Prix 2025
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# ✗ Could not load Hungarian Grand Prix: any API: 500 calls/h
# core           INFO 	Loading data for Dutch Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# ✗ Could not load Dutch Grand Prix: any API: 500 calls/h
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# ✗ Could not load Italian Grand Prix: any API: 500 calls/h
# core           INFO 	Loading data for Azerbaijan Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# ✗ Could not load Azerbaijan Grand Prix: any API: 500 calls/h
# core           INFO 	Loading data for Singapore Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# ✗ Could not load Singapore Grand Prix: any API: 500 calls/h
# core           INFO 	Loading data for United States Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# ✗ Could not load United States Grand Prix: any API: 500 calls/h
# core           INFO 	Loading data for Mexico City Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# ✗ Could not load Mexico City Grand Prix: any API: 500 calls/h
# core           INFO 	Loading data for São Paulo Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# ✗ Could not load São Paulo Grand Prix: any API: 500 calls/h
# core           INFO 	Loading data for Las Vegas Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# ✗ Could not load Las Vegas Grand Prix: any API: 500 calls/h
# core           INFO 	Loading data for Qatar Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# ✗ Could not load Qatar Grand Prix: any API: 500 calls/h
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.8.1]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# ✗ Could not load Abu Dhabi Grand Prix: any API: 500 calls/h
# Done — 259 rows

# %% [markdown]
# # Create CSV file with all of the data
